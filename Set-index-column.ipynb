# %%
import pandas

# %%
df1 = pandas.read_csv("No-header-data.txt", header = None)
df1
# Out:
#    0     1       2               3     4             5
# 0  1  3266      St   San Francisco   USA   Angela Shop
# 1  2   735      St   San Francisco   USA   Bready Shop
# 2  3   332      St   San Francisco   USA    Rocko Shop

# %%
df1.columns=["SNO", "ID", "CITY", "STATE", "COUNTRY", "SHOPE_NAME"]
df1
# Out:
#    SNO    ID    CITY           STATE COUNTRY    SHOPE_NAME
# 0    1  3266      St   San Francisco     USA   Angela Shop
# 1    2   735      St   San Francisco     USA   Bready Shop
# 2    3   332      St   San Francisco     USA    Rocko Shop

# %%
df1.set_index("SNO")
# Out:
#        ID    CITY           STATE COUNTRY    SHOPE_NAME
# SNO
# 1    3266      St   San Francisco     USA   Angela Shop
# 2     735      St   San Francisco     USA   Bready Shop
# 3     332      St   San Francisco     USA    Rocko Shop

# %%
df1
# Out:
#    SNO    ID    CITY           STATE COUNTRY    SHOPE_NAME
# 0    1  3266      St   San Francisco     USA   Angela Shop
# 1    2   735      St   San Francisco     USA   Bready Shop
# 2    3   332      St   San Francisco     USA    Rocko Shop

# %%
df2 = df1.set_index("SNO")
df2
# Out:
#        ID    CITY           STATE COUNTRY    SHOPE_NAME
# SNO
# 1    3266      St   San Francisco     USA   Angela Shop
# 2     735      St   San Francisco     USA   Bready Shop
# 3     332      St   San Francisco     USA    Rocko Shop

# %%
df1.set_index("ID", inplace=True)
df1
# Out:
#         CITY           STATE COUNTRY    SHOPE_NAME
# ID
# 3266      St   San Francisco     USA   Angela Shop
# 735       St   San Francisco     USA   Bready Shop
# 332       St   San Francisco     USA    Rocko Shop

# %%
df1.set_index("CITY", inplace=True, drop=False)
df1
# Out:
#           CITY           STATE COUNTRY    SHOPE_NAME
# CITY
#    St       St   San Francisco     USA   Angela Shop
#     St      St   San Francisco     USA   Bready Shop
#     St      St   San Francisco     USA    Rocko Shop
